# %%
print("长者")

# %%
import numpy as np
data=np.array([[1,2,3],[4,5,6]])
print(data)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
A=np.array([[1,2,3],[4,5,6]])
print(A)

# %%
D=A*data
print(D)

# %%
print(D[1][2])

# %%
D=D.flatten()
print(D)
D [D>20]

# %%
import matplotlib.pyplot as plt

# %%
x=np.arange(0,6,0.01)
y1=np.sin(x)
y2=np.cos(x)

# %%
plt.plot(x,y1,label='sin')
plt.plot(x,y2,linestyle="--",label='cos')
plt.xlabel("x")
plt.ylabel("y")
plt.title('sin&cos')
plt.legend()
plt.show()

# %%
from matplotlib.image import imread
img=imread('C:\\Users\\admin\\Desktop\\123.jpg')
plt.imshow(img)

plt.show()
